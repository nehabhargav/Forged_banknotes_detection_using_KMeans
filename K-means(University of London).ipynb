# %%
import pandas as pd
data = pd.read_csv('~/Desktop/happyscore_income.csv', engine='python')
print(data)
happy = data['happyScore']
income = data['avg_income']
ineq = data['income_inequality']
income.min()
# Out:
#          country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 0         Armenia                     37               4.9              2.42
# 1          Angola                     26               4.3              3.19
# 2       Argentina                     60               7.1              1.91
# 3         Austria                     59               7.2              2.11
# 4       Australia                     65               7.6              1.80
# ..            ...                    ...               ...               ...
# 106       Uruguay                     58               7.0              2.13
# 107       Vietnam                     53               6.1              1.77
# 108  South Africa                     49               6.3              2.47
# 109        Zambia                     37               5.0              2.61
# 110      Zimbabwe                     33               4.1              2.16
#
# ...

# %%
import matplotlib.pyplot  as  plt
plt.xlabel("Income")
plt.ylabel("Happiness")
plt.scatter(income,happy)

# %%
happy = data.happyScore
print(happy)
# Out:
# 0      4.350
# 1      4.033
# 2      6.574
# 3      7.200
# 4      7.284
#        ...
# 106    6.485
# 107    5.360
# 108    4.642
# 109    5.129
# 110    4.610
# Name: happyScore, Length: 111, dtype: float64

# %%
plt.xlabel("Income")
plt.ylabel("happiness")
plt.scatter(income,happy, s= ineq*10, alpha= 0.25)

# %%
import pandas as pd
data = pd.read_csv('~/Desktop/happyscore_income.csv', engine='python')

data.sort_values('avg_income', inplace=True)

richest = data[data['avg_income'] > 1500]
richest.iloc[-1]
# Out:
# country                       Luxembourg
# adjusted_satisfaction                  66
# avg_satisfaction                      7.7
# std_satisfaction                     1.76
# avg_income                        26182.3
# median_income                     22240.2
# income_inequality                   31.95
# region                   'Western Europe'
# happyScore                          6.946
# GDP                               1.56391
# country                        Luxembourg
# Name: 61, dtype: object

# %%
import numpy as np
data.sort_values('avg_income', inplace=True)

richest = data[data['avg_income'] > 15000]
rich_mean = np.mean(richest['avg_income'])
all_mean = np.mean(data['avg_income'])
print(rich_mean,all_mean)
# Out:
# 19266.68075388889 6442.75141618018

# %%
plt.scatter(richest['avg_income'], richest['happyScore'])
plt.text(richest.iloc[0]['avg_income'],
        richest.iloc[0]['happyScore'],
         richest.iloc[0]['country'])
plt.text(richest.iloc[-1]['avg_income'],
        richest.iloc[-1]['happyScore'],
         richest.iloc[-1]['country'])
# Out:
# Text(26182.275, 6.946000000000001, 'Luxembourg')

# %%
for k,row in richest.iterrows():
    print(row["country"])
# Out:
# Italy
# Ireland
# Sweden
# United Kingdom
# Belgium
# Finland
# Denmark
# France
# Netherlands
# Iceland
# Germany
# Austria
# Australia
# Canada
# Norway
# United States
# Switzerland
# Luxembourg

# %%
richest = data[data['avg_income'] > 15000]
plt.scatter(richest['avg_income'], richest['happyScore'])
for k,row in richest.iterrows():
    plt.text(row['avg_income'],
             row['happyScore'],
             row['country']
            )
plt.xlabel("Income")
plt.ylabel("Happiness")
# Out:
# Text(0, 0.5, 'Happiness')

# %%
from sklearn.cluster import KMeans

import numpy as np 
income_happy = np.column_stack((income,happy))
km = KMeans(n_clusters=3).fit(income_happy)
clusters = km.cluster_centers_
plt.scatter(income,happy)
plt.scatter(clusters[:,0] , clusters[:,1], s= 1000)

# %%
data.head()
# Out:
#
# country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 10     Burundi                     25               2.9              1.96
# 65  Madagascar                     33               3.7              1.86
# 58     Liberia                     37               4.4              2.02
# 72  Mozambique                     34               3.8              1.76
# 73       Niger                     34               3.8              1.75
#
#     avg_income  median_income  income_inequality                region  \
# 10      572.88         436.92          33.360000  'Sub-Saharan Africa'
# 65      574.20         415.48          40.720000  'Sub-Saharan Africa'
# 58      653.04         528.72          36.480000  'Sub-Saharan Africa'
# 72      714.72         488.52          45.580000  'Sub-Saharan Africa'
# 73      718.40         535.56          37.726667  'Sub-Saharan Africa'
#
#     happyScore      GDP     country
# 10       2.905  0.01530     Burundi
# ...

# %%
inceq = data['income_inequality']
gdp = data['GDP']
plt.scatter(inceq,gdp)
richest = data[data['avg_income'] > 15000]
filt_gdp = data[data['GDP'] > 0.5 ]
plt.scatter(filt_gdp['income_inequality'], filt_gdp['GDP'], alpha = 0.25)
plt.xlabel("Rate Of  Income Inequality")
plt.ylabel("Rate of GDP")
for k ,row in data.iterrows():
            for k in 5:
                plt.text(row['income_inequality'],
                row['GDP'],
                row['country']
                  )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-352c2705bf79> in <module>
#       8 plt.ylabel("Rate of GDP")
#       9 for k ,row in data.iterrows():
# ---> 10             for k in 5:
#      11                 plt.text(row['income_inequality'],
#      12                 row['GDP'],
#
# TypeError: 'int' object is not iterable

# %%
print(inceq.iloc[0])
print(inceq.iloc[-1])
print(gdp.iloc[0])
print(gdp.iloc[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-7c344fc2c494> in <module>
# ----> 1 print(inceq.iloc[0])
#       2 print(inceq.iloc[-1])
#       3 print(gdp.iloc[0])
#       4 print(gdp.iloc[-1])
#
# NameError: name 'inceq' is not defined

# %%
one = bd['gum']
two = bd['boot']

in = np.column_stack((one,two))
km = KMeans(n_clusters=3).fit(income_happy)
clusters = km.cluster_centers_
plt.scatter(one,two)
plt.scatter(clusters[:,0] , clusters[:,1], s= 1000)
# Out:
#   File "<ipython-input-1-af1ca0812093>", line 5
#     in = np.column_stack((one,two))
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# You need to:
#
# Step 1: Load the given Banknote authentication dataset.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot  as  plt
import numpy as np
import pandas as pd
bd = pd.read_csv('~/Desktop/banknotes.csv',engine='python')
plt.scatter(bd.gum,bd.boot, alpha= 0.25)
on = bd['gum']
tw = bd['boot']

gum_boot = np.column_stack((on,tw))
print(gum_boot)
kmeansresult =  KMeans(n_clusters=3).fit(gum_boot)
plt.scatter(on,tw)
ct = kmeansresult.cluster_centers_
plt.scatter(ct[:,0], ct[:,1], s= 500)
plt.savefig('fogu')

plt.xlabel("Varience")
plt.ylabel("Skewness")
# Out:
# [[  3.6216    8.6661 ]
#  [  4.5459    8.1674 ]
#  [  3.866    -2.6383 ]
#  ...
#  [ -3.7503  -13.4586 ]
#  [ -3.5637   -8.3827 ]
#  [ -2.5419   -0.65804]]
# Text(21.875, 0.5, 'Skewness')

# %%
Please insert your description here.
# I use the full data set taken from the link:
# This banknote authentication dataset is a simplified version of the dataset available on OpenML.
# https://www.openml.org/d/1462
# banknote-authentication_21-05-2015_by_Rafael_G.Mantovani.csv
names = ["V1","V2","V3","V4","Class"]data = pd.read_csv('data/banknote-authentication_21-05-2015_by_Rafael_G.Mantovani.csv', header=1, names=names)

mean V1:0.4314 , V2:1.9174 
std V1:2.8425 , V2:5.8684

n_clusters=2 (real ones, fake)clusters = km_res.cluster_centers_ 
array([[-0.12376677, -3.45591265],
[ 0.86602181, 6.1238775 ]])

# having an array of labels km_red. labels_ divide all the data into 2 groups
# the entire data set is divided via labels_ (Labels of each point)
# my_labels = km_res.labels_
my_real_ones = data.iloc[np.where(my_labels == 0)]
my_fake      = data.iloc[np.where(my_labels == 1)]
# Out:
#   File "<ipython-input-15-ec8ea7141d8b>", line 1
#     Please insert your description here.
#                 ^
# SyntaxError: invalid syntax

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot  as  plt
import numpy as np
import pandas as pd
bd = pd.read_csv('~/Desktop/banknotes.csv',engine='python')
plt.scatter(bd.gum,bd.boot, alpha= 0.25)
on = bd['gum']
tw = bd['boot']

gum_boot = np.column_stack((on,tw))

kmeansresult =  KMeans(n_clusters=2).fit(gum_boot)
plt.scatter(on,tw)
ct = kmeansresult.cluster_centers_
plt.scatter(ct[:,0], ct[:,1], s= 500)
plt.savefig('two_cluster')
plt.text


plt.xlabel("Varience")
plt.ylabel("Skewness")
# Out:
# Text(21.875, 0.5, 'Skewness')

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot  as  plt
import numpy as np
import pandas as pd
bd = pd.read_csv('~/Desktop/banknotes.csv',engine='python')
plt.scatter(bd.gum,bd.boot, alpha= 0.25)
on = bd['gum']
tw = bd['boot']

plt.xlabel("Varience")
plt.ylabel("Skewness")
gum_boot = np.column_stack((on,tw))

kmeansresult =  KMeans(n_clusters=5).fit(gum_boot)
plt.scatter(on,tw)
ct = kmeansresult.cluster_centers_
plt.scatter(ct[:,0], ct[:,1], s= 500)
plt.savefig('seven_cluster')

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot  as  plt
import numpy as np
import pandas as pd
bd = pd.read_csv('~/Desktop/banknotes.csv',engine='python')
plt.scatter(bd.gum,bd.boot, alpha= 0.25)
on = bd['gum']
tw = bd['boot']
plt.xlabel("Varience")
plt.ylabel("Skewness")
gum_boot = np.column_stack((on,tw))

kmeansresult =  KMeans(n_clusters=7).fit(gum_boot)
plt.scatter(on,tw)
ct = kmeansresult.cluster_centers_
plt.scatter(ct[:,0], ct[:,1], s= 500)
plt.savefig('seven_cluster')

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot  as  plt
import numpy as np
import pandas as pd
bd = pd.read_csv('~/Desktop/banknotes.csv',engine='python')
plt.scatter(bd.gum,bd.boot, alpha= 0.25)
on = bd['gum']
tw = bd['boot']
plt.xlabel("Varience")
plt.ylabel("Skewness")
gum_boot = np.column_stack((on,tw))

kmeansresult =  KMeans(n_clusters=4).fit(gum_boot)
plt.scatter(on,tw)
ct = kmeansresult.cluster_centers_
plt.scatter(ct[:,0], ct[:,1], s= 500)
plt.savefig('fourclusters')
